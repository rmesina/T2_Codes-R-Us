# %%
import pandas as pd

# %%
df = pd.read_csv('match_summary.csv')

# %%
df
# Out:
#       match.id            team1                   team2  team1.goals  \
# 0      2499719          Arsenal          Leicester City            4
# 1      2499720  Manchester City  Brighton & Hove Albion            1
# 2      2499721          Burnley                 Chelsea            3
# 3      2499722   Crystal Palace       Huddersfield Town            0
# 4      2499723       Stoke City                 Everton            0
# ...        ...              ...                     ...          ...
# 1936   2058013           Sweden                 England            0
# 1937   2058014           France                 Belgium            1
# 1938   2058015          England                 Croatia            0
# 1939   2058016          Belgium                 England            2
# 1940   2058017          Croatia                  France            2
#
#       team2.goals  team1.shots  team2.shots  team1.shots.target  \
# 0               3           27            7                  10
# 1               0           12            6                   3
# 2               2            9           15                   5
# 3               2           11            8                   3
# 4               1           10            8                   1
# ...           ...          ...          ...                 ...
# 1936            2            6           11                   3
# 1937            0           17            9                   5
# 1938            1            8           14                   0
# 1939            0           11           14                   4
# 1940            2           14            7                   3
#
#       team2.shots.target  team1.passes  ...  team1.corners  team2.corners  \
# 0                      4           513  ...              9              4
# 1                      2           682  ...             10              3
# 2                      5           245  ...              5              8
# 3                      6           291  ...             12              9
# 4                      3           205  ...              7              6
# ...                  ...           ...  ...            ...            ...
# 1936                   2           280  ...              1              6
# 1937                   2           282  ...              4              5
# 1938                   4           245  ...              3              5
# 1939                   5           427  ...              4              5
# 1940                   5           429  ...              6              2
#
#       team1.offsides  team2.offsides  team1.fouls  team2.fouls  team1.yellows  \
# 0                  6               2            9           12              0
# 1                  1               6            9            6              2
# 2                  1               2           11           18              3
# 3                  0               2            7           19              1
# 4                  6               2           10           13              1
# ...              ...             ...          ...          ...            ...
# 1936               2               1           11            7              2
# 1937               1               1            8           16              2
# 1938               3               0            9           17              1
# 1939               1               0           12            5              1
# 1940               1               1           13           13              1
#
#       team2.yellows  team1.reds  team2.reds
# 0                 1           0           0
# 1                 0           0           0
# 2                 5           0           1
# 3                 3           0           0
# 4                 1           0           0
# ...             ...         ...         ...
# 1936              1           0           0
# 1937              3           0           0
# 1938              1           0           0
# 1939              2           0           0
# 1940              2           0           0
#
# [1941 rows x 25 columns]

# %%
team1 = [cols for cols in df.columns if cols.startswith('team1')]

# %%
team1
# Out:
# ['team1',
#  'team1.goals',
#  'team1.shots',
#  'team1.shots.target',
#  'team1.passes',
#  'team1.pass.acc',
#  'team1.possession',
#  'team1.corners',
#  'team1.offsides',
#  'team1.fouls',
#  'team1.yellows',
#  'team1.reds']

# %%
team2 = [i for i in df.iloc[:,1:].columns if i not in team1]

# %%
team2
# Out:
# ['team2',
#  'team2.goals',
#  'team2.shots',
#  'team2.shots.target',
#  'team2.passes',
#  'team2.pass.acc',
#  'team2.possession',
#  'team2.corners',
#  'team2.offsides',
#  'team2.fouls',
#  'team2.yellows',
#  'team2.reds']

# %%
team1 = df[team1]

# %%
team1.to_csv('team1info.csv')

# %%
team2 = df[team2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fp/4dqsnfmn6_sccky6kgrdvxjr0000gn/T/ipykernel_5374/998534423.py in <module>
# ----> 1 team2 = df[team2]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3443         # Do we have a (boolean) DataFrame?
#    3444         if isinstance(key, DataFrame):
# -> 3445             return self.where(key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10734         try_cast=lib.no_default,
#   10735     ):
# > 10736         return super().where(cond, other, inplace, axis, level, errors, try_cast)
#   10737
#   10738     @deprecate_nonkeyword_arguments(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9030             )
#    9031
# -> 9032         return self._where(cond, other, inplace, axis, level, errors=errors)
#    9033
#    9034     @final
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors)
#    8786                 for dt in cond.dtypes:
#    8787                     if not is_bool_dtype(dt):
# -> 8788                         raise ValueError(msg.format(dtype=dt))
#    8789         else:
#    8790             # GH#21947 we have an empty DataFrame/Series, could be object-dtype
#
# ValueError: Boolean array expected for the condition, not object

# %%
team2.to_csv('team2info.csv')
