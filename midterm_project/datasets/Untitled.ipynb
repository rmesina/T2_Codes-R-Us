# %%
import pandas as pd
import os

# %%
filenames = [i for i in os.listdir('./') if i.endswith('.csv')]
filenames
# Out:
# ['competitions.csv', 'teams.csv', 'players.csv']

# %%
for index, filename in enumerate(filenames):
    globals()[f"dataframe_{filename.split('.')[0]}"]= pd.read_csv('./{}'.format(filename))

# %%
dataframe_competitions.head()
# Out:
#    Unnamed: 0                    name  wyId           format  \
# 0           0  Italian first division   524  Domestic league
# 1           1  English first division   364  Domestic league
# 2           2  Spanish first division   795  Domestic league
# 3           3   French first division   412  Domestic league
# 4           4   German first division   426  Domestic league
#
#                                                 area  type
# 0  {'name': 'Italy', 'id': '380', 'alpha3code': '...  club
# 1  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 4  {'name': 'Germany', 'id': '276', 'alpha3code':...  club

# %%
dataframe_competitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      int64
#  1   name        7 non-null      object
#  2   wyId        7 non-null      int64
#  3   format      7 non-null      object
#  4   area        7 non-null      object
#  5   type        7 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 464.0+ bytes

# %%
dataframe_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    142 non-null    int64
#  1   city          142 non-null    object
#  2   name          142 non-null    object
#  3   wyId          142 non-null    int64
#  4   officialName  142 non-null    object
#  5   area          142 non-null    object
#  6   type          142 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 7.9+ KB

# %%
dataframe_players
# Out:
#       Unnamed: 0                                       passportArea  weight  \
# 0              0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1              1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2              2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3              3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4              4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
# ...          ...                                                ...     ...
# 3598        3598  {'name': 'Tunisia', 'id': 788, 'alpha3code': '...      72
# 3599        3599  {'name': 'Peru', 'id': 604, 'alpha3code': 'PER...      76
# 3600        3600  {'name': 'Peru', 'id': 604, 'alpha3code': 'PER...      78
# 3601        3601  {'name': 'Morocco', 'id': 504, 'alpha3code': '...      70
# 3602        3602  {'name': 'Panama', 'id': 591, 'alpha3code': 'P...       0
#
# ...

# %%
filenames = [i for i in os.listdir('./match_data') if i.endswith('.csv')]
filenames
# Out:
# ['match_European_Championship.csv',
#  'match_England.csv',
#  'match_Germany.csv',
#  'match_Italy.csv',
#  'match_World_Cup.csv',
#  'match_France.csv',
#  'match_Spain.csv']

# %%
for index, filename in enumerate(filenames):
    globals()[f"dataframe_{filename.split('.')[0]}"]= pd.read_csv('./match_data/{}'.format(filename))

# %%
dataframe_match_European_Championship
# Out:
#     Unnamed: 0  status  roundId  gameweek  \
# 0            0  Played  4165474         0
# 1            1  Played  4165473         0
# 2            2  Played  4165473         0
# 3            3  Played  4165472         0
# 4            4  Played  4165472         0
# 5            5  Played  4165472         0
# 6            6  Played  4165472         0
# 7            7  Played  4165471         0
# 8            8  Played  4165471         0
# 9            9  Played  4165471         0
# 10          10  Played  4165471         0
# 11          11  Played  4165471         0
# 12          12  Played  4165471         0
# 13          13  Played  4165471         0
# 14          14  Played  4165471         0
# 15          15  Played  4165470         3
# 16          16  Played  4165470         3
# 17          17  Played  4165470         3
# 18          18  Played  4165470         3
# 19          19  Played  4165470         3
# 20          20  Played  4165470         3
# ...

# %%
gamedf = pd.concat([dataframe_match_European_Championship, dataframe_match_England, dataframe_match_Germany, dataframe_match_Italy, dataframe_match_World_Cup, dataframe_match_France, dataframe_match_Spain])

# %%
gamedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1941 entries, 0 to 379
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1941 non-null   int64
#  1   status         1941 non-null   object
#  2   roundId        1941 non-null   int64
#  3   gameweek       1941 non-null   int64
#  4   teamsData      1941 non-null   object
#  5   seasonId       1941 non-null   int64
#  6   dateutc        1941 non-null   object
#  7   winner         1941 non-null   int64
#  8   venue          1835 non-null   object
#  9   wyId           1941 non-null   int64
#  10  label          1941 non-null   object
#  11  date           1941 non-null   object
#  12  groupName      99 non-null     object
#  13  referees       1941 non-null   object
#  14  duration       1941 non-null   object
#  15  competitionId  1941 non-null   int64
# dtypes: int64(7), object(9)
# memory usage: 257.8+ KB

# %%
gamedf
# Out:
#      Unnamed: 0  status  roundId  gameweek  \
# 0             0  Played  4165474         0
# 1             1  Played  4165473         0
# 2             2  Played  4165473         0
# 3             3  Played  4165472         0
# 4             4  Played  4165472         0
# ..          ...     ...      ...       ...
# 375         375  Played  4406122         1
# 376         376  Played  4406122         1
# 377         377  Played  4406122         1
# 378         378  Played  4406122         1
# 379         379  Played  4406122         1
#
#                                              teamsData  seasonId  \
# 0    {'9905': {'scoreET': 1, 'coachId': 137521, 'si...      9291
# 1    {'3148': {'scoreET': 0, 'coachId': 134365, 'si...      9291
# 2    {'10682': {'scoreET': 0, 'coachId': 136439, 's...      9291
# 3    {'7839': {'scoreET': 0, 'coachId': 210205, 'si...      9291
# 4    {'3148': {'scoreET': 1, 'coachId': 134365, 'si...      9291
# ...

# %%
gamedf.teamsData
# Out:
# 0      {'9905': {'scoreET': 1, 'coachId': 137521, 'si...
# 1      {'3148': {'scoreET': 0, 'coachId': 134365, 'si...
# 2      {'10682': {'scoreET': 0, 'coachId': 136439, 's...
# 3      {'7839': {'scoreET': 0, 'coachId': 210205, 'si...
# 4      {'3148': {'scoreET': 1, 'coachId': 134365, 'si...
#                              ...
# 375    {'691': {'scoreET': 0, 'coachId': 169425, 'sid...
# 376    {'756': {'scoreET': 0, 'coachId': 167044, 'sid...
# 377    {'692': {'scoreET': 0, 'coachId': 3880, 'side'...
# 378    {'674': {'scoreET': 0, 'coachId': 210074, 'sid...
# 379    {'696': {'scoreET': 0, 'coachId': 117648, 'sid...
# Name: teamsData, Length: 1941, dtype: object

# %%
teamData = dict(gamedf.teamsData)

# %%
teamData
# Out:
# {0: 0    {'9905': {'scoreET': 1, 'coachId': 137521, 'si...
#  0    {'1646': {'scoreET': 0, 'coachId': 8880, 'side...
#  0    {'2444': {'scoreET': 0, 'coachId': 14710, 'sid...
#  0    {'3162': {'scoreET': 0, 'coachId': 251025, 'si...
#  0    {'9598': {'scoreET': 0, 'coachId': 122788, 'si...
#  0    {'3783': {'scoreET': 0, 'coachId': 210513, 'si...
#  0    {'676': {'scoreET': 0, 'coachId': 92894, 'side...
#  Name: teamsData, dtype: object,
#  1: 1    {'3148': {'scoreET': 0, 'coachId': 134365, 'si...
#  1    {'1628': {'scoreET': 0, 'coachId': 8357, 'side...
#  1    {'2482': {'scoreET': 0, 'coachId': 272299, 'si...
#  1    {'3158': {'scoreET': 0, 'coachId': 210119, 'si...
#  1    {'2413': {'scoreET': 0, 'coachId': 276858, 'si...
#  1    {'3804': {'scoreET': 0, 'coachId': 220743, 'si...
#  1    {'679': {'scoreET': 0, 'coachId': 3427, 'side'...
#  Name: teamsData, dtype: object,
#  2: 2    {'10682': {'scoreET': 0, 'coachId': 136439, 's...
# ...

# %%
test = teamData[379]

# %%
teamData[379]
# Out:
# 379    {'1609': {'scoreET': 0, 'coachId': 7845, 'side...
# 379    {'3159': {'scoreET': 0, 'coachId': 20386, 'sid...
# 379    {'3780': {'scoreET': 0, 'coachId': 228969, 'si...
# 379    {'696': {'scoreET': 0, 'coachId': 117648, 'sid...
# Name: teamsData, dtype: object

# %%
test
# Out:
# 379    {'1609': {'scoreET': 0, 'coachId': 7845, 'side...
# 379    {'3159': {'scoreET': 0, 'coachId': 20386, 'sid...
# 379    {'3780': {'scoreET': 0, 'coachId': 228969, 'si...
# 379    {'696': {'scoreET': 0, 'coachId': 117648, 'sid...
# Name: teamsData, dtype: object

# %%
for i in test[:1]:
    print(i)
# Out:
# {'1609': {'scoreET': 0, 'coachId': 7845, 'side': 'home', 'teamId': 1609, 'score': 4, 'scoreP': 0, 'hasFormation': 1, 'formation': {'bench': [{'playerId': 20612, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 25662, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 7864, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 230020, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 26010, 'ownGoals': '0', 'redCards': '0', 'goals': '1', 'yellowCards': '0'}, {'playerId': 7879, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 7870, 'ownGoals': '0', 'redCards': '0', 'goals': '1', 'yellowCards': '0'}], 'lineup': [{'playerId': 370224, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 120339, 'ownGoals': '0', 'redCards': '0', 'goals': '0', 'yellowCards': '0'}, {'playerId': 7945, 'ownGoals': '0', 'redCard
# ...
